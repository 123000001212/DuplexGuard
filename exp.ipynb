# %% [markdown]
# #### Craft $D_a$ and $D_s$

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main-SA.py --net="ResNet18" --dataset="CIFAR10" --data_path="/home/data" --eps=8 --patch_size=12
# Out:
# Spliting Dc and Du: Size of Dc is 45000, Du is 5000.
# -------------Da generation started.-------------------------
# Monday, 24. June 2024 04:05PM
# ...

# %% [markdown]
# #### Verify the unlearned model

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u eval_p-value.py --net="ResNet18" --dataset="CIFAR10" --data_path="/home/data" --eps=8 --patch_size=12
# Out:
# Files already downloaded and verified
# Data mean is [0.4914672374725342, 0.4822617471218109, 0.4467701315879822],
# Data std  is [0.24703224003314972, 0.24348513782024384, 0.26158785820007324].
# Files already downloaded and verified
# tau= 0.01
# D1_num = 450 ; D2_num = 2000 ; Dunlearn_num= 5000
# Monday, 24. June 2024 10:57PM
# ...
